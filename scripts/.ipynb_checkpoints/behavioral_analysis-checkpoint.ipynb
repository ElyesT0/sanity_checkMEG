# %%
# Imports
from modules import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib qt
    
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_rows', 150)      # Display up to 150 rows
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Preparing the dataset
df=pd.read_csv(path_merged)
df_full=drop_subjects_with_less_rows(df,'subject_id')

# %%
# 1. General Performance
#  -- a. Mean DL on sequences
#  -- b. Mean error rates on sequences
#
# 2. Learning analysis
#  -- a. Before vs after rest : Error rate and DL distance
#  -- b. Structure learning : chunking evolution (look at article from Fagot)
#
# 3. Awareness Scale - Dynamics over trials

# %% [markdown]
# '*******************************
# ### 1. General Performance
# '*******************************

# %% [markdown]
# <b>1.a. Mean DL on Sequences</b>

# %%
full_exp_sub=[]
print(f'There are {len(full_exp_sub)} Participants that have completed the full experiment.')
# Out:
# There are 0 Participants that have completed the full experiment.

# %%
with open('modules/file_names.json', 'r') as file:
    json_file_names=json.load(file)

# %%
json_file_names['experiment']['processed']
# Out:
# {'1': '/Volumes/T5_EVO/1-experiments/REPLAYSEQ/7-data_neurospin/2-main_behavioral_file/processed/sub-01/sub-01-processed_meg_behavioral.csv',
#  '2': '/Volumes/T5_EVO/1-experiments/REPLAYSEQ/7-data_neurospin/2-main_behavioral_file/processed/sub-02/sub-02-processed_meg_behavioral.csv',
#  '3': '/Volumes/T5_EVO/1-experiments/REPLAYSEQ/7-data_neurospin/2-main_behavioral_file/processed/sub-03/sub-03-processed_meg_behavioral.csv',
#  '15': '/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/behavior/processed/sub-15/sub-15-processed_meg_behavioral.csv',
#  '14': '/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/behavior/processed/sub-14/sub-14-processed_meg_behavioral.csv',
#  '13': '/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/behavior/processed/sub-13/sub-13-processed_meg_behavioral.csv',
#  '11': '/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/behavior/processed/sub-11/sub-11-processed_meg_behavioral.csv',
# ...

# %%
path_save_merged_behavioral
# Out:
# '/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/behavior/merged'

# %%
path_merged="/Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/behavior/processed/merged/merged_behavioral_megSeq.csv"
df=pd.read_csv(path_merged)

# %%
all_ids=sorted(df['subject_id'].unique())

# %%
def drop_subjects_with_less_rows(df, subject_col):
    """
    Drops subjects that don't have the maximum number of rows.
    
    Parameters:
        df (pd.DataFrame): The DataFrame containing subject data.
        subject_col (str): The column name for subject IDs.
    
    Returns:
        pd.DataFrame: The filtered DataFrame with only subjects having the maximum number of rows.
    """
    # Calculate the number of rows per subject
    rows_per_subject = df[subject_col].value_counts()
    max_rows = rows_per_subject.max()
    
    # Identify subjects to drop
    subjects_to_drop = rows_per_subject[rows_per_subject < max_rows].index.tolist()
    
    # Print the dropped subjects
    print(f"Dropping subjects with fewer rows than the max ({max_rows} rows).\nSubjects that were dropped: {subjects_to_drop}")
    
    # Filter the DataFrame to keep only subjects with max rows
    filtered_df = df[df[subject_col].isin(rows_per_subject[rows_per_subject == max_rows].index)]
    
    return filtered_df

# %%
df_full=drop_subjects_with_less_rows(df,'subject_id')
# Out:
# Dropping subjects with fewer rows than the max (270 rows).
# Subjects that were dropped: [3]

# %%
df['subject_id'].unique()

# %%
run_preliminary_behavioral_pipeline()
# Out:
# /opt/anaconda3/envs/mne_python/lib/python3.9/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/mne_python/lib/python3.9/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
