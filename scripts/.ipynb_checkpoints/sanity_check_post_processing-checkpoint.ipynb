# %% [markdown]
# # Sanity Check -- Post Processing
# Version: 1 <br>
# Creator: Elyès Tabbane <br>
# Acquisition Date: 10.10.2024 <br>
# Participant: 11 <br>
# Center: Neurospin <br>
# Description: Data post MNE BIDS pipeline
# <br><br>

# %%
# Imports
from modules import *
# %load_ext autoreload
# %autoreload 2

pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_rows', 150)      # Display up to 150 rows

# %%
for i in range(0,18):
    run=i
    print('----------------------------')
    print(f'*********** RUN-{run+1} ***********')
    print('----------------------------')
    
    inspect_raw(run,post_processing=True)
# Out:
# ----------------------------
# *********** RUN-1 ***********
# ----------------------------
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1291x922 with 4 Axes>
# Effective window size : 2.048 (s)
# Plotting power spectral density (dB=True).
# /Users/et/Documents/UNICOG/8-MEG/sanity_checkMEG/scripts/modules/functions_sanity_check.py:459: FutureWarning: The value of `amplitude='auto'` will be removed in MNE 1.8.0, and the new default will be `amplitude=False`.
#   raw.compute_psd().plot()
# /opt/anaconda3/envs/mne_python/lib/python3.9/site-packages/mne/viz/utils.py:167: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# ----------------------------
# *********** RUN-2 ***********
# ----------------------------
# <MNELineFigure size 1000x600 with 4 Axes>
# <MNEBrowseFigure size 1291x922 with 4 Axes>
# Effective window size : 2.048 (s)

# %% [markdown]
# ---
# <div style="background-color: lightblue; padding: 10px; font-size: 30px;">
#     Plot Evoked response for [ITEMS]
# </div>

# %%
plot_evoked(epo_item_path,baseline=[-0.05,0])
# Out:
# Reading /Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/derivatives/items/sub-08/meg/sub-08_task-reproduction_epo.fif ...
#     Found the data of interest:
#         t =    -192.00 ...     592.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 58 columns
# 3240 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# <MNELineFigure size 1000x600 with 4 Axes>

# %% [markdown]
# ---
# <div style="background-color: lightblue; padding: 10px; font-size: 30px;">
#     Plot Topographic Maps for epochs [ITEMS]
# </div>

# %%
evoked=mne.read_epochs(epo_item_path).average()
times = np.arange(0.1, 0.301, 0.02)
evoked.plot_topomap(times, ch_type="mag")
evoked.plot_topomap(times, ch_type="grad")
# Out:
# Reading /Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/derivatives/items/sub-08/meg/sub-08_task-reproduction_epo.fif ...
#     Found the data of interest:
#         t =    -192.00 ...     592.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 58 columns
# 3240 matching events found
# No baseline correction applied
# 0 projection items activated
# <MNEFigure size 1650x220 with 12 Axes>
# <MNEFigure size 1650x220 with 12 Axes>
# <MNEFigure size 1650x220 with 12 Axes>

# %% [markdown]
# ---
# <div style="background-color: lightblue; padding: 10px; font-size: 30px;">
#     Plot Evoked response for [SEQUENCES]
# </div>

# %%
plot_evoked(epo_sequence_path,baseline=[None,0])
# Out:
# Reading /Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/derivatives/sequence/sub-08/meg/sub-08_task-reproduction_epo.fif ...
#     Found the data of interest:
#         t =    -192.00 ...   12288.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 58 columns
# 270 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)

# %% [markdown]
# ---
#
# <div style="background-color: lightblue; padding: 10px; font-size: 30px;">
#     Compare Evoked per Sequences
# </div>

# %%
compare_evoked(epo_sequence_path)
# Out:
# Reading /Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/derivatives/sequence/sub-08/meg/sub-08_task-reproduction_epo.fif ...
#     Found the data of interest:
#         t =    -192.00 ...   12288.00 ms
#         0 CTF compensation matrices available
# Adding metadata with 58 columns
# 270 matching events found
# No baseline correction applied
# 0 projection items activated
# Replacing existing metadata with 14 columns
# Multiple channel types selected, returning one figure per type.
# combining channels using RMS (mag channels)
# combining channels using RMS (mag channels)
# combining channels using RMS (mag channels)
# combining channels using RMS (mag channels)
# combining channels using RMS (mag channels)
# combining channels using RMS (mag channels)
# combining channels using RMS (mag channels)
# combining channels using RMS (mag channels)
# combining channels using RMS (mag channels)
# combining channels using RMS (grad channels)
# combining channels using RMS (grad channels)
# ...

# %% [markdown]
# ---
# <div style="background-color: lightblue; padding: 10px; font-size: 30px;">
#     Decoding
# </div>

# %%
run_decoding_sanity_check(sub_nb)
# Out:
# Reading /Volumes/T5_EVO/1-experiments/REPLAYSEQ/2-Data/derivatives/items/sub-08/meg/sub-08_task-reproduction_epo.fif ...
#     Found the data of interest:
#         t =    -192.00 ...     592.00 ms
#         0 CTF compensation matrices available
# /Users/et/Documents/UNICOG/8-MEG/sanity_checkMEG/scripts/modules/functions_decoding.py:160: UserWarning: Careful, this function only works for epochs before rejection
#   warnings.warn("Careful, this function only works for epochs before rejection", UserWarning)
# Adding metadata with 58 columns
# 3240 matching events found
# No baseline correction applied
# 0 projection items activated
# np.shape(epochs) :  (3240, 343, 50)
# Replacing existing metadata with 15 columns
# Applying baseline correction (mode: mean)
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# ...
